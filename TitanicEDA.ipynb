# %% [markdown]
# This is an EDA for the train.csv file of the Titanic Dataset
# I will begin by including the information that will be explicitly required by the assignment and we'll see what else develops along the way.  For this assignment I will be exploring the following variables: PassengerID, Survived, PClass, Sex, Age,  Sibsp, Parch, Ticket, Fare, Cabin, and Embarked.

# %% [markdown]
# The information that will be collected for each variable will include (but is not limited to): variable type, continuous or categorical; whether or not it has missing variables; if the variable is continuous we'll grab information such as min, max, mean, standard deviation; a histogram.

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# YAY! Data frame! So far so good. Now time to get my hands dirty.

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
342/891.0
# Out:
# 0.3838383838383838

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# dtype: int64

# %% [markdown]
# Doing a value_counts() on PassengerId was not the smartest idea considering every PassengerId should be unique. PassengerId is a nominal categorical variable. Each Id is used only to distinguish one passenger from the next and does not necessarily imply a value oriented sequence.

# %% [markdown]
# The next question to ask: do all passengers have a passenger Id?

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# A hisotgram of PassengerId would show us that each ID between 1 and 891 would have a value of 1. Not entirely useful information about the PassengerId field.  So we know that PassengerId is a nominal field and that every passenger has a unique PassengerId.

# %% [markdown]
# The Survived field should prove a bit more interesting than PassengerId.  This field is nominal categorical; either the passenger survived (1) or the passenger did not (0). Let's take a look at the value_counts().

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %% [markdown]
# The sum of 549 and 342 is 891 which corresponds to the total number of passengers in the csv which means that no null values exist in this field.  Let's verify that.

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# No null values in the Survived field confirmed. Let's visualize this survived data!

# %%
df.Survived.value_counts().plot(kind='barh')

# %% [markdown]
# So we see that we have our 342 in the survived bar and 549 in the did not survive bar.

# %% [markdown]
# Next, we explore the Pclass, or passenger class, field.

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %% [markdown]
# So it looks like we have three different class types: 1, 2, and 3. This value is categorical and in this case ordinal as well since moving in numerical order we may be going to a higher or lower class. To find out it would make sense to compare what fares were paid by each class. First, if we sum up the counts for each class we get 891 (out of 891 total passengers).  Let's verify that there are no null values.

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# Empty! Fantastic.

# %%
df.Pclass.value_counts().plot(kind = 'barh')

# %% [markdown]
# When you compare the amounts of passengers in each class you can see that almost 500 of the passengers are found in class 3 which I would now assume is the lowest class. This assumption would be stronger if I took a look at the amount paid by each passenger in each class.

# %%
df[df.Pclass == 3].Fare.hist(bins = 25)

# %%
df[df.Pclass == 2].Fare.hist(bins = 25)

# %%
df[df.Pclass == 1].Fare.hist(bins=25)

# %% [markdown]
# From the distribution of ticket price for Pclass 3, the majority of passengers paid just under $10. Most of the Pclass 2 passengers paid over ten dollars.  Lastly, passengers of class 1 appear to have paid the most for their spots on the Titanic.

# %%
df[(df.Pclass == 1) & (df.Fare<150)].Fare.hist(bins=25)

# %% [markdown]
# The above histogram shows me what each passenger paid for their class 1 ticket for fares less than 100 dollars. We see now tha the many passengers paid about 30 dollars and another large group of passengers paid around 80 dollars.

# %% [markdown]
# It would be quite interesting to see how class might play in whether or not a passenger survived.  Let's take a look!

# %%
fig, axs = plt.subplots(1,2)
df[df.Pclass == 1].Survived.value_counts().plot(kind='barh', ax=axs[0], title="Class 1 Survivorship")
df[df.Pclass == 2].Survived.value_counts().plot(kind='barh', ax=axs[1], title="Class 2 Survivorship")

# %%
df[df.Pclass == 3].Survived.value_counts().plot(kind='barh', title="Class 3 Survivorship")

# %% [markdown]
# It now looks like if a passenger were of class 1, they were more likely to survive.  Passengers of class 2 had worse odds, but it looks like it is close to a fifty fifty split.  The passengers of class 3 were more likely to not survive.

# %% [markdown]
# Sex, the gender of each passenger, can be broken down to either male or female, hence it is a nominal (categorical) variable. Let's take a look at the numbers.

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %% [markdown]
# 577 male passengers on board and 314 female passengers on board for a total of 891 passengers. Let's verify that there are no null values in this field.

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
Adf.Sex.value_counts().plot(kind='barh')

# %% [markdown]
# The field Age refers to the age of each passenger on board and it is our first continuous field.

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# 177 of our 891 listed passengers have a null age.

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# Age Count: 714 (714 non-null values), Minimum = 0.42, Maximum = 80.00, Mean = 29.70, Standard Deviation = 14.53

# %%
df.Age.hist()

# %% [markdown]
# Most of the passengers listed are in their 20s to 30s.

# %% [markdown]
# The SibSp field describes the number of siblings or spouses that a passenger had.  This is another continuous variable.

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# It appears that all of the passengers siblings/spousal information is accounted for.

# %%
df.SibSp.describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %% [markdown]
# The minimum number of siblings and/or spouses that any passenger had was 0, the maximum was 8 (big family!), the mean value is 0.52, and the standard deviation is 1.10.

# %%
df.SibSp.hist()

# %% [markdown]
# Parch is also a continuous field and it represents the number of parents/children aboard.

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# It looks like all parent and child information is accounted for.

# %%
df.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %% [markdown]
# The minimum number of parents/children that any passenger had was 0, the maximum was 6, the mean value is 0.38, and the standard deviation is 0.81.

# %%
df.Parch.hist()

# %% [markdown]
# The ticket field displays the ticket number of the ticket held by the passenger.  This is a nominal categorical field.

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There are no null instances in the Ticket field.

# %%
df.Ticket.describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# Name: Ticket, dtype: object

# %% [markdown]
# So it appears that 891 tickets are accounted for but only 681 of those tickets are unique. This is intriguing. Perhaps the children of parents shared their parent's ticket? Let's take a look at the passengers who shared the ticket CA. 2343 to find out if there is any connection among them.

# %%
df[df.Ticket == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# The data fram above confirms my first assumption.  These passengers are all part of the Sage family.

# %% [markdown]
# Fare is a continuous field which indicates the amount a passenger paid for their ticket. Let's see what kinds of values are in the Fare field.

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# No null values in fare. The distribution however will reveal that some values are zero, a fact that was pointed out in one of the video lectures.

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# The minimum value paid for a ticket by any passenger was zero dollars.  The maximum value paid for a ticket by a passenger was 512 dollars.  The average amount paid for a ticket was 32.20 dollars. The standard deviation of this data is 49.69.

# %%
df.Fare.hist()

# %% [markdown]
# The Cabin field refers to the cabin that the passenger stayed in.  This field is a nominal (categorical) field.

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# B77                2
# C65                2
# D26                2
# E24                2
# E25                2
# B20                2
# C93                2
# D33                2
# E67                2
# D35                2
# D36                2
# C52                2
# F4                 2
# C125               2
# C124               2
#                   ..
# F G63              1
# A6                 1
# D45                1
# D6                 1
# D56                1
# C101               1
# C54                1
# D28                1
# D37                1
# B102               1
# D30                1
# E17                1
# ...

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# It appears that a significat number of members of this trip did not have a cabin.  This portion of the passengers would most likely include the lower class passengers (2nd and 3rd class).  Let's take a look!

# %%
df[(df.Pclass == 3) | (df.Pclass == 2)].Cabin.value_counts()
# Out:
# G6       4
# F2       3
# F33      3
# D        3
# E101     3
# F G73    2
# F4       2
# E121     2
# F38      1
# F G63    1
# D56      1
# E77      1
# F E69    1
# E10      1
# dtype: int64

# %%
df[df.Pclass == 1].Cabin.value_counts()
# Out:
# C23 C25 C27        4
# B96 B98            4
# C22 C26            3
# E25                2
# B51 B53 B55        2
# E24                2
# E8                 2
# B57 B59 B63 B66    2
# C68                2
# D20                2
# C65                2
# B77                2
# D26                2
# B58 B60            2
# C93                2
# E67                2
# D33                2
# B28                2
# D35                2
# C78                2
# D36                2
# B22                2
# C52                2
# B20                2
# C125               2
# C124               2
# C126               2
# C123               2
# D17                2
# B5                 2
#                   ..
# C47                1
# C45                1
# D6                 1
# A6                 1
# B3                 1
# C54                1
# C101               1
# D37                1
# B102               1
# D30                1
# E17                1
# E58                1
# ...

# %% [markdown]
# The above inputs and outputs lets us know that passengers of class one were the ones who had cabins. This data could be correlated with survivorship, but since I do not believe that the two are going to be particularly related, I won't look into it in this assignment.  If I were to try to find a correlation of cabin to survivorship I would need to evaluate the survivorship of class since we saw that the higher your class, the more likely it was that you survived.  It might be interesting to see at some point how proximity to life rafts affected survivorship, but again, there are bigger fish to fry.

# %% [markdown]
# The last field we will look at is Embarked which describes the port of embarkation.  This field is categorical.  Let's see what information we are provided with.

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %% [markdown]
# We see that we have 644 passengers embarking from Southhampton (S), 168 from Cherbourg (C), and 77 from Queenstown (Q), which totals to 889, two short of our total df.  Let's see who's point of embarkating we are missing.

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %% [markdown]
# Both women here are survivors, in first class, generally older, traveling alone but under the same ticket and in the same cabin. Perhaps Amelie Icard was Mrs. Stone's caretaker? After a quick search, I found that Miss Icard traveled as Mrs. Stone's maid! It is also listed on that website (http://www.encyclopedia-titanica.org/titanic-survivor/amelia-icard.htm) that the women boarded at Southampton which would mean that our total for S should be 646 (not 644). This missing data was easy to reconcile unlike some of the other missing data, like age.

# %%
df.Embarked.value_counts().plot(kind = 'barh')
